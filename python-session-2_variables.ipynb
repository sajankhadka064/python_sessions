# %% [markdown]
# # Variables:

# %%
0b1110
# Out:
# 14

# %%
0o123
# Out:
# 83

# %%
number=3-5j
number.real
number.conjugate()
# Out:
# (3+5j)

# %% [markdown]
# complex(4,10)
# # real = 4
# # image=10
# 4+10j

# %%
complex()
# Out:
# 0j
