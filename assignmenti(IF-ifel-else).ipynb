# %%
num = eval(input("Enter the number: "))

rem = 0


rem = rem + (num % 10000)
num = num // 10000

rem = rem + (num % 1000)
num = num // 1000

rem = rem + (num % 1000)
num = num // 1000

rem = rem + (num % 100)
num = num // 100

rem = rem + (num % 10)
num = num // 10

rem = rem + (num % 1)
num = num // 1

print(rem)

# %%
NUM=eval(input("enter a  5 digit number"))
REM=0

REM=REM+((NUM//10)+1)
NUM=NUM%10

REM=REM*10+((NUM//1)+1)
print (REM)
# Out:
# enter a  5 digit number 12
# 23

# %%
NUM=eval(input("enter a  5 digit number"))
REM=0

REM=REM+((NUM//10000)+1)

N1=((NUM//1000)%10)+1
REM=REM*10+N1

N2=((NUM//100)%10)+1
REM=REM*10+N2

N3=((NUM//10)%10+1)
REM=REM*10+N3

N4=((NUM//1)%10)+1
REM=REM*10+N4

print(NUM)
print (REM)
# Out:
# enter a  5 digit number 12371
# 12371
# 23482

# %%
print('enter the temperature',end=)
print(":")
# Out:
#   Cell In[8], line 1
#     print('enter the temperature',end=)
#                                   ^
# SyntaxError: expected argument value expression

# %%
print('hai',end='-->')
print(
    'how'))
# Out:
#   Cell In[12], line 3
#     'how'))
#           ^
# SyntaxError: unmatched ')'
