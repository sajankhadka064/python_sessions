# %%
list1=[10,20,30]
list2=['cat','egg','hat']
list1.index(10)
# Out:
# 0

# %%
list1=[10,20,30]
list2=['cat','egg','hat']
list1.index(10)
# Out:
# 0

# %%
list1=[10,20,10,30]
f_in= list1.index(10)
i2=list1.index(10,f_in +1)
print(i2)
# Out:
# 2

# %%
list1=[10,20,10,30]
i2=list1.index(10,list1.index(10)+1)
print(i2)
# Out:
# 2

# %%
list3=['welcomehelo']
list3.index('w')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 list3=['welcomehelo']
# ----> 2 list3.index('w')
#
# ValueError: 'w' is not in list

# %%
list2=['cat','egg','hat']
list2.index('cat')
# Out:
# 0

# %%
list3=['w','e','l','c','o','m','e','h','e','l','o']
list3.index('w')
# Out:
# 0

# %%
list3=['w','e','l','c','o','m','e','h','e','l','o']
list3.index('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 list3=['w','e','l','c','o','m','e','h','e','l','o']
# ----> 2 list3.index('z')
#
# ValueError: 'z' is not in list

# %% [markdown]
# ## insert

# %%
dir(list1)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list1=[10,20,30]
list2=['cat','egg','hat']
list1.insert(2,'x')
list2.insert(3,99)
print(list1)
print(list2)
# Out:
# [10, 20, 'x', 30]
# ['cat', 'egg', 'hat', 99]

# %%
list1=[10,20,30]
list2=['cat','egg','hat']
list1.append(list2)
print(list1)
# Out:
# [10, 20, 30, ['cat', 'egg', 'hat']]

# %%
list1=[11,22,33]
list2=['a','b','c']
list1.insert(2,'x')
list1
# Out:
# [11, 22, 'x', 33]

# %%
list1=[11,22,33]
list2=['a','b','c']
list1.append(list2)
list1
# Out:
# [11, 22, 33, ['a', 'b', 'c']]

# %% [markdown]
# ## REVERSE

# %%
list1=[11,22,33]
list2=['a','b','c']
list1.reverse()
list2.reverse()
print(list1,end=' ')
print(list2)
# Out:
# [33, 22, 11] ['c', 'b', 'a']

# %% [markdown]
# $$descending

# %%
list1=[22,33,55]
list2=['a','b','c']
list1.reverse()
list2.reverse()
print(list1,end=' ')
print(list2)
# Out:
# [55, 33, 22] ['a', 'b', 'c']

# %% [markdown]
# $$ascending

# %%
list1=[55,22,11]
list2=['C','B','A']
list1.reverse()
list2.reverse()
print(list1,end=' ')
print(list2)
# Out:
# [11, 22, 55] ['A', 'B', 'C']

# %%
list1=[22,33,55]
list2=['a','b','c']
printt(reversed(list1),reversed(list2))

# %%
list1=[22,33,55]
list2=['a','b','c']
print(reversed(list1),reversed(list2))
for i in list1:
    print(i,end=' ')
print(" ")
for i in list2:
    print(i,end=' ')
# Out:
# <list_reverseiterator object at 0x000001926F357730> <list_reverseiterator object at 0x000001927812D810>
# 22 33 55
# a b c

# %% [markdown]
# ## sort

# %%
list1=[55,22,11]
list2=['C','B','A']
print(sorted(list1))
print(sorted(list2))
# Out:
# [11, 22, 55]
# ['A', 'B', 'C']

# %%
list1=['a','b','c']
list2=['c','b','a']
print(sorted(list1))
print(sorted(list2))
# Out:
# ['a', 'b', 'c']
# ['a', 'b', 'c']

# %%
list1=[55,22,11]
list2=['C','B','A']
list1.sort()
list2.sort()
print(list1,list2)
# Out:
# [11, 22, 55] ['A', 'B', 'C']

# %%
list1=[11,22,55]
list2=['a','b','c']
list1.sort()
list2.sort()
print(list1,list2)
# Out:
# [11, 22, 55] ['a', 'b', 'c']

# %%
TUPPLE=()
dir(TUPPLE)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']
