# %% [markdown]
# ## FUNCTION

# %%
def addition():
    n1=20
    n2=10
    print("sum of {} and {} is {}".format(n1,n2,n1+n2))

addition()

# %%
def hello():
    n1=eval(input("enter a number"))
    print('hello')
    print("Iam writing a function")

hello()
# Out:
# enter a number 12
# hello
# Iam writing a function

# %%
def avg():
    n1=eval(input("enter the first number"))
    n2=eval(input("enter the second number"))
    n3=eval(input("enter the third number"))
    AVG=(n1+n2+3)/3
    print("average:",AVG)

avg()
# Out:
# enter the first number 12
# enter the second number 12
# enter the third number 12
# average: 9.0

# %%
def avg1():
     try:
        n1=eval(input("enter the first number"))
        n2=eval(input("enter the second number"))
        n3=eval(input("enter the third number"))
        AVG=(n1+n2+n33)/3
        print("average:",AVG)

     except Exception as e:
         print(e)


avg1()
# Out:
# enter the first number
# invalid syntax (<string>, line 0)

# %%
import random
def even_odd():
    num= random.randint(1,100)
    if num%2==0:
         print("{} is even number".format(num))

    else:
         print(num,"is odd number")

even_odd()
# Out:
# 21 is odd number

# %%
def addition (n1,n2):
    print("this addition ", end='')
    print("function")
    print(" sum :",n1+n2)

def substraction(n1,n2):
    print("this is substraction function")
    print("difference:",n1-n1)

def multiplication(n1,n2):
    print("this is multiplication function")
    print("product :",n1*n2)

addition (100,10)
substraction(1000,200)
multiplication(12,130)
# Out:
# this addition function
#  sum : 110
# this is substraction function
# difference: 0
# this is multiplication function
# product : 1560

# %%
num
